# %%
from numpy import array
from numpy.linalg import norm
from math import inf
v=array([1,2,3])
b=array([1,2,3])
l1=norm(v,1)
l2=norm(v)
print(l2)
# Out:
# 3.7416573867739413

# %%
A=array([[1,2,3],[1,2,3]])
print(A)
# Out:
# [[1 2 3]
#  [1 2 3]]

# %%
from numpy import 
A=a
